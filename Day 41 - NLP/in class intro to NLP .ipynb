# %% [markdown]
# # $Natural-Language-Processing-(NLP)$
# - subfield of AI, that focuses on interaction between computers and humans (natural language)
# - Natural Language ---> language that humans speak
# - it is not simple like computer languages
# -
# - computer languages have well defined syntax
# - sure natural languages have grammer
#     - is that grammer followed all the times?
#     - no. not all times
#     - that is what makes natural language complex
# -
# - humans say something, mean something totally else
# - NLP ---> linguistics, computer science, AI
#
# -
# - Challenges with NL:
#     - NL always needs context:
#         - Example:
#         - `it is freexing here`
#         - does it mean cold? temperature?
#         - it is a request, asking someone to please close the window
#     -
#     - Words with two meanings:
#         - `bat`
#         - `i saw a boy with a bat`
#         - do you mean the boy had a bat (something to play with)
#         - or do you mean he had a bat (bird)
#     -
#         - eg. `I saw a man on a hill with a telescope`
#         - did you see a man on a hill, using a telescope?
#         - Or did you just see a man on a hill, and he was carrying a telescope?
#
#     - Sarcasm
#         - `Oh great a flat tire is exactly what i needed today`
#     - Tone
#         - `Boss: I would be grateful if you could provide an update that was due yesterday.`
#         - `Boss: Could you please give me the update now? you were supposed to do that yesterday.`
#     - Slang
#         - informal ways of communication
#         - words are not included in dictionary
#     - Typing errors
#         - hitting wrong keys
#         - `i just wnted to wasah my car`
#         - we as humans have no problem understanding, but for a machine these can be tough

# %% [markdown]
# ## What do we do in NLP
#
# Applications:
# - Text classification
# - Information Retrieval
# - Natural Language Understanding
# - Natural Language Generation
# -
# -
# - Real world Applications:
#     - personal assistants ---> siri, alexa
#     - machine translation ---> language translations
#     - customer support ---> chatbots powered with NLP work 24/7
#     - Sentiment Analysis ---> businesses use this for analysing social feedback for products
#     - ...
# -
# -

# %% [markdown]
# ## General Pipeline of NLP
# - not a specific series of steps
# - a combination of lot of processes
# -
# - whenever there is an NLP pipeline, you will see these operations
# - everyone should know
# - taking inputs from users, you implement these processes too
# -
# - Phases are different stages of understanding, what the NL means
# - ![](https://media.geeksforgeeks.org/wp-content/uploads/20250501151836945933/Phases-of-NLP.webp)
# -

# %% [markdown]
# [Phases of NLP](https://www.geeksforgeeks.org/machine-learning/phases-of-natural-language-processing-nlp/)

# %% [markdown]
# - NLP pipelines, series of steps taken to deal with NL data
# -
# - ![](https://media.geeksforgeeks.org/wp-content/uploads/20230118132334/NLP-Pipeline-GIF.gif)
# -

# %% [markdown]
# ## **Text Preprocessing**

# %% [markdown]
# 1. Tokenization
# 2. Lowercasing
# 3. Stop word Removal
# 4. Punctuation Removal
# 5. Stemming/ Lemmatization

# %% [markdown]
# ### Tokenization

# %% [markdown]
# - split text into smaller units
# - Sentence tokenization
# - Word tokenization
# -
# -

# %%
review = "The laptop is fast and efficient, and helps me finish my job well"

# %%
words = review.split()
words

len(words)

# %%
# input data
# string operations

text = """
Forests are nature’s living cathedrals, where towering trees weave a green canopy that hums with life. 
Beneath their shade, the air feels cooler, richer, and alive with the scent of earth and leaves. 
Sunlight filters through in golden shards, dancing on mossy ground and whispering streams. 
Every rustle in the undergrowth hints at hidden creatures—birds calling from above, 
insects buzzing in the air, and animals moving quietly in the shadows. Forests are not just collections 
of trees; they are breathing, evolving worlds that shelter countless species, 
store ancient secrets, and remind us of the delicate balance that sustains life on Earth.
"""

# %%
sentences = text.split(".")
sentences

len(sentences)

# %%
words = text.split()
words

len(words)

# %%
characters = list(text.replace(" ", ""))
characters

len(characters)

# %% [markdown]
# > Exercise: Counting Frequencies of specific words
# - text = "The mission to Mars is a major step in space exploration. To reach Mars, scientists must build a reliable spacecraft. Finding water on Mars is a critical goal for this mission. If astronauts can extract water on Mars, the Mars mission will be much safer. The surface of Mars is harsh, but Mars remains our best hope for a successful mission."
#
# - Count the frequency of `mars`, `mission`, `the`
# -

# %%
text = "The mission to Mars is a major step in space exploration. To reach Mars, scientists must build a reliable spacecraft. Finding water on Mars is a critical goal for this mission. If astronauts can extract water on Mars, the Mars mission will be much safer. The surface of Mars is harsh, but Mars remains our best hope for a successful mission."

# text = text.lower()

# %%
x = text.count("mars")
x
 
y = text.count("the")
z = text.count("mission")
 
print(f"The frequency of text Mars: {x}, the: {y} and mission: {z}")

# %%
text.count("mars") / len(text.split())

# %%
text.count("mission") / len(text.split())

# %%
text.count("the") / len(text.split())

# %% [markdown]
# ### 2. Stop word Removal
# - frequently occuring words that don't add too much meaning to the text
# - eg. is, the, and, an
# - articles: the, a, an
# - prepositions: in, on, at
# - conjunctions: and, or, but
# - pronouns: I, you, he, she
# - Auxillary verbs: is, am, are
# -

# %%
text = text.lower().split()
len(text) # we are using 61 tokens

# %%
stopwords = ['the', 'a', 'an',  'in', 'on', 'at', 'and', 'or', 'but', 'I', 'you', 'he', 'she', 'is', 'am', 'are']

# text ---> tokens
# tokens - stopwords ---> Clean text

clean_text = [word for word in text if word not in stopwords]
len(clean_text) # we only use 47

# %%
# punctuation removal
# . , / : ; \n

newtext = text

newtext = newtext.replace(".", "")
newtext = newtext.replace(",", "")
newtext = newtext.replace(":", "")
newtext = newtext.replace(";", "")
newtext = newtext.replace("\n", "")

newtext = newtext.lower()

newtext = newtext.split()

newtext = [word for word in newtext if word not in stopwords]
newtext

# %% [markdown]
# ### Exercise:
#
# 1. Ask the user for prompt
# 2. create a function that caculates the tokens in user input prompt
#     - lowercase, tokenize
#     - calcualte the initial number of tokens used
#     - stop word removal
#     - calculate new number of tokens
#     - set_limit = 50
#     - give user a warning if the limit is reached
#         - implement it on the prompt
#         - Say "here is the answer", or "say token limit reached, Recharge!!"
#
# 3. this function will take user's input as prompt
#
# > 25 Minutes

# %% [markdown]
# - you can connect an LLM with your machine
# -
# - you keep this validation to limit the number of tokens used
#     - if a user enters number of words more than set limit
#         - then you do not prompt the LLM
#         - and you ask the user to revise the prompt
#         - give back to them their previous prompt
#         -
#     - User revises the prompt
#         - you apply the validation again
#         - if set limit is not crossed
#         - then you prompt LLM or you ask them to revise

# %%
print("Please insert your prompt")
user_input = input("Ask me a question: ")
 
def prompt(user_input):
 
    # Original Prompt
    print("Initial prompt by user:")
    print("-"*30)
    print(f"{user_input}")
    print("="*30)
    
 
    # Lowercase
    newtext = user_input.lower()
 
    # Tokenize
    newtext_token = user_input.split()
 
    # Number of token
    newtext_number_of_token = len(newtext_token)
    
    print(f"Number of token {newtext_number_of_token}")
    print("="*30)
 
    # Stop word removal
    stopwords = ['the', 'a', 'an', 'in', 'on', 'at', 'and', 'or', 'but',
                 'i', 'you', 'he', 'she', 'is', 'am', 'are']
   
    clean_newtext = [word for word in newtext_token if word not in stopwords]
 
    # Calculate new tokens
    newtext_token_after_removal = len(clean_newtext)
    
    print(f"Number of token after removal of stop words: {newtext_token_after_removal}")
    print("="*30)
 
    # Set limit = 50
    set_limit = 50
 
    # warning
    if newtext_token_after_removal < set_limit:
        print("="*30)
        print("Looking for answers, wait for the response...")
        print("="*30)
        print(f"Here are the answer: ")
        print("="*30)
        print(f"{clean_newtext}")
        print("="*30)
 
    else:
        print("="*30)
        print("\nToken has reached limit. Suscribe our plan for further usage")
 
prompt(user_input)

# %% [markdown]
# ---
#
# ### Text Preprocessing with NLTK

# %% [markdown]
# NLTK - library for NLP
# - most of the preprocessing can be done using NLTK
# - We use it for text preprocessing pipelines
# -

# %%
# pip install nltk

# %%
text = """
Forests are nature’s living cathedrals, where towering trees weave a green canopy that hums with life. 
Beneath their shade, the air feels cooler, richer, and alive with the scent of earth and leaves. 
Sunlight filters through in golden shards, dancing on mossy ground and whispering streams. 
Every rustle in the undergrowth hints at hidden creatures—birds calling from above, 
insects buzzing in the air, and animals moving quietly in the shadows. Forests are not just collections 
of trees; they are breathing, evolving worlds that shelter countless species, 
store ancient secrets, and remind us of the delicate balance that sustains life on Earth.
"""

# %%
import nltk

from nltk.tokenize import sent_tokenize, word_tokenize, WhitespaceTokenizer

nltk.download('punkt') # needed for tokenization
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\devid\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sentences = sent_tokenize(text)

# punctuation aware tokenization
words = word_tokenize(text) # punctuations as tokens too
words
# Out:
# ['Forests',
#  'are',
#  'nature',
#  '’',
#  's',
#  'living',
#  'cathedrals',
#  ',',
#  'where',
#  'towering',
#  'trees',
#  'weave',
#  'a',
#  'green',
#  'canopy',
#  'that',
#  'hums',
#  'with',
#  'life',
#  '.',
#  'Beneath',
#  'their',
#  'shade',
#  ',',
#  'the',
#  'air',
#  'feels',
#  'cooler',
#  ',',
#  'richer',
#  ',',
#  'and',
#  'alive',
#  'with',
#  'the',
#  'scent',
#  'of',
#  'earth',
#  'and',
#  'leaves',
#  '.',
#  'Sunlight',
#  'filters',
#  'through',
#  'in',
#  'golden',
#  'shards',
#  ',',
#  'dancing',
#  'on',
#  'mossy',
#  'ground',
#  'and',
#  'whispering',
#  'streams',
#  '.',
#  'Every',
#  'rustle',
#  'in',
#  'the',
#  'undergrowth',
#  'hints',
#  'at',
#  'hidden',
#  'creatures',
#  '—',
#  'birds',
#  'calling',
#  'from',
#  'above',
#  ',',
#  'insects',
#  'buzzing',
#  'in',
#  'the',
#  'air',
#  ',',
#  'and',
#  'animals',
#  'moving',
#  'quietly',
#  'in',
#  'the',
#  'shadows',
#  '.',
#  'Forests',
#  'are',
# ...

# %%
from nltk.corpus import stopwords

stopwords = stopwords.words('english')

filter_stopwords = [w for w in words if w not in stopwords]
filter_stopwords
# Out:
# ['Forests',
#  'nature',
#  '’',
#  'living',
#  'cathedrals',
#  ',',
#  'towering',
#  'trees',
#  'weave',
#  'green',
#  'canopy',
#  'hums',
#  'life',
#  '.',
#  'Beneath',
#  'shade',
#  ',',
#  'air',
#  'feels',
#  'cooler',
#  ',',
#  'richer',
#  ',',
#  'alive',
#  'scent',
#  'earth',
#  'leaves',
#  '.',
#  'Sunlight',
#  'filters',
#  'golden',
#  'shards',
#  ',',
#  'dancing',
#  'mossy',
#  'ground',
#  'whispering',
#  'streams',
#  '.',
#  'Every',
#  'rustle',
#  'undergrowth',
#  'hints',
#  'hidden',
#  'creatures',
#  '—',
#  'birds',
#  'calling',
#  ',',
#  'insects',
#  'buzzing',
#  'air',
#  ',',
#  'animals',
#  'moving',
#  'quietly',
#  'shadows',
#  '.',
#  'Forests',
#  'collections',
#  'trees',
#  ';',
#  'breathing',
#  ',',
#  'evolving',
#  'worlds',
#  'shelter',
#  'countless',
#  'species',
#  ',',
#  'store',
#  'ancient',
#  'secrets',
#  ',',
#  'remind',
#  'us',
#  'delicate',
#  'balance',
#  'sustains',
#  'life',
#  'Earth',
#  '.']

# %%
import string

punctuations = list(string.punctuation)
punctuations

# %%
filter_punctuations = [w for w in words if w not in punctuations]
filter_punctuations
# Out:
# ['Forests',
#  'are',
#  'nature',
#  '’',
#  's',
#  'living',
#  'cathedrals',
#  'where',
#  'towering',
#  'trees',
#  'weave',
#  'a',
#  'green',
#  'canopy',
#  'that',
#  'hums',
#  'with',
#  'life',
#  'Beneath',
#  'their',
#  'shade',
#  'the',
#  'air',
#  'feels',
#  'cooler',
#  'richer',
#  'and',
#  'alive',
#  'with',
#  'the',
#  'scent',
#  'of',
#  'earth',
#  'and',
#  'leaves',
#  'Sunlight',
#  'filters',
#  'through',
#  'in',
#  'golden',
#  'shards',
#  'dancing',
#  'on',
#  'mossy',
#  'ground',
#  'and',
#  'whispering',
#  'streams',
#  'Every',
#  'rustle',
#  'in',
#  'the',
#  'undergrowth',
#  'hints',
#  'at',
#  'hidden',
#  'creatures',
#  '—',
#  'birds',
#  'calling',
#  'from',
#  'above',
#  'insects',
#  'buzzing',
#  'in',
#  'the',
#  'air',
#  'and',
#  'animals',
#  'moving',
#  'quietly',
#  'in',
#  'the',
#  'shadows',
#  'Forests',
#  'are',
#  'not',
#  'just',
#  'collections',
#  'of',
#  'trees',
#  'they',
#  'are',
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Stemming
# - Reduce words to their root form by chopping off the suffixes
# - running ---> run
# -
# - we remove `affixes`
#     - Prefixes
#         - undo
#         - `un`
#     - Suffixes
#         - running
#         - `ing`
#
# - Infixes
#     - a word between two words
#         - abso-`bloody`-lutely
# - Circumfixes
#     - words that cover words on both sides
#         - `en`light`en`
#         -
#
# - Examples:
#     - running ---> run
#     - happier ---> happi
#     - quickly ---> quick
#     -
#     - changing ---> chang
#     - changed ---> chang
#     - change ---> chang
#     -
#     - studying ---> studi
#     - studies ---> studi
#     - study ---> studi
#
#     -
#     - Improve ---> Improv
#     - Improving ---> Improv
#     - Improvements ---> Improv
#     - Improved ---> Improv
#     - Improver ---> Improv

# %% [markdown]
# Generously, Provision, Friendliness
# - Porter
#     - generally used, moderately aggresive
#         - gener, provis, friendli
#
# - Snowball
#     - sligtly faster
#         - generous, provis, friendli
#
# - Lancaster
#     - very agressive
#         - gen, provid, friend

# %%
from nltk.stem import PorterStemmer, SnowballStemmer, LancasterStemmer

ps = PorterStemmer()
sb = SnowballStemmer(language= 'english')
ls = LancasterStemmer()

words = ['Generously', 'Provision', 'Friendliness']

p_stem = [ps.stem(word) for word in words]

s_stem = [sb.stem(word) for word in words]

l_stem = [ls.stem(word) for word in words]

print(p_stem, s_stem, l_stem)
# Out:
# ['gener', 'provis', 'friendli'] ['generous', 'provis', 'friendli'] ['gen', 'provid', 'friend']

# %%
# [x**0.5 for x in range(10) if x %2 ==0]
# Out:
# [0.0, 1.4142135623730951, 2.0, 2.449489742783178, 2.8284271247461903]

# %% [markdown]
# ### Lemmatization
# - converts words to their roots or base forms, considering grammer as well
# - provide contextually more meaninful base forms
# - words to their base forms ---> Lemma
#
# -
# - Examples
#
#     - better ---> good
#     -
#     - Improve ---> Improve
#     - Improving ---> Improve
#     - Improvements ---> Improve
#     - Improved ---> Improve
#     - Improver ---> Improve

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# download a dictionary
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\devid\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
lemmatizer.lemmatize('us', 'n')

lemmatizer.lemmatize('anything')
# Out:
# 'anything'

# %%
lemmatizer = WordNetLemmatizer()

words = ['Generously', 'Provision', 'Friendliness', 'Improving', 'Studying', 'Enlighten', 'Best', 'Better']

lemma_words = [lemmatizer.lemmatize(word.lower()) for word in words]
lemma_words
# Out:
# ['generously',
#  'provision',
#  'friendliness',
#  'improving',
#  'studying',
#  'enlighten',
#  'best',
#  'better']

# %% [markdown]
# pos (str)
# - The Part Of Speech tag.
# - Valid options are “n” for nouns, “v” for verbs, “a” for adjectives, “r” for adverbs and “s” for satellite adjectives.

# %%
lemma_words = [lemmatizer.lemmatize(word.lower(), pos='v') for word in words] # ing --> cut off
lemma_words
# Out:
# ['generously',
#  'provision',
#  'friendliness',
#  'improve',
#  'study',
#  'enlighten',
#  'best',
#  'better']

# %% [markdown]
# ## SpaCy
# spaCy is one of the best text analysis library. spaCy excels at large-scale information extraction tasks and is one of the fastest in the world.

# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("Forests are breathing and evolving worlds that shelter countless species.") # corpus of text
for token in doc:
    print(token.text, token.lemma_)
# Out:
# Forests forest
# are be
# breathing breathe
# and and
# evolving evolve
# worlds world
# that that
# shelter shelter
# countless countless
# species specie
# . .

# %%
words = 'Generously Provision Friendliness Improving Studying Enlighten Best Better'
words = nlp(words.lower())

for token in words:
    print(token.text, token.lemma_)
# Out:
# generously generously
# provision provision
# friendliness friendliness
# improving improve
# studying study
# enlighten enlighten
# best well
# better well

# %% [markdown]
# ---
